# %% [markdown]
# ### Imports

# %%
from googlemaps import Client as GoogleMaps
import pandas as pd

# %% [markdown]
# Read in Master Project List as Excel file and create dataframe

# %%
# read an excel file and convert 
# into a dataframe object
df = pd.DataFrame(pd.read_excel(r'/Users/heatherphillips/Library/CloudStorage/OneDrive-TheUniversityofMontana/Capstone/MRA Project/Data/MRA List.xlsx'))
  
# show the dataframe
#df

# %% [markdown]
# Create vatiable for Google Maps API Key

# %%
gmaps = GoogleMaps('AIzaSyDNh4cgsqoLAya9m5RzO_yPi3BrfPX-ogM')

# %% [markdown]
# Add Long and Lat Columns to DF

# %%
df['long'] = ""
df['lat'] = ""

# %%
#df

# %% [markdown]
# Function to find Lat and Lon

# %%
for x in range(len(df)):
    try:
        #time.sleep(10) #to add delay in case of large DFs
        geocode_result = gmaps.geocode(df['Combined Address'][x])
        df['lat'][x] = geocode_result[0]['geometry']['location'] ['lat']
        df['long'][x] = geocode_result[0]['geometry']['location']['lng']
    except IndexError:
        print("Address was wrong...")
    except Exception as e:
        print("Unexpected error occurred.", e )
#df.head()
# Out:
# /var/folders/c9/tml_1y352dq8ww51cft4c9vh0000gn/T/ipykernel_19036/1416648092.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lat'][x] = geocode_result[0]['geometry']['location'] ['lat']
# /var/folders/c9/tml_1y352dq8ww51cft4c9vh0000gn/T/ipykernel_19036/1416648092.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['long'][x] = geocode_result[0]['geometry']['location']['lng']
# Address was wrong...
#   PROJECT TYPE  FISCAL YEAR FINAL AMT PAID DISTRICT     PROJECT NAME  \
# 0           PP                      1981.0        1       Caras Park
# ...

# %% [markdown]
# Save DF as Excel Fil

# %%
df.to_excel(r'/Users/heatherphillips/Library/CloudStorage/OneDrive-TheUniversityofMontana/Capstone/MRA Project/Data/MRA List Edited.xlsx', index=False)
